# %%
#### This is an exemplary JupyterNotebook for CEF-SsL
#### This Notebook demonstrates how to use CEF-SsL for a binary classification on a snippet of the "fixed" version of the CICIDS17 dataset
#### The code below can be adapted for any dataset by simply changing the features used to train the ML models, and specifying the path of the data

# %%
import os
import time
import math
from pathlib import Path
from pprint import pprint
import time
import sys
cwd = os.getcwd()
from functions import *
import sklearn
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None

# %%
print("scikit-learn version: {}".format(sklearn.__version__))
print("Pandas version: {}".format(pd.__version__))
print("NumPy version: {}".format(np.__version__))
# Out:
# scikit-learn version: 0.23.1
# Pandas version: 1.0.5
# NumPy version: 1.18.5

# %%
############# PARAMETERS ###############

F_holdout = 0.20   # FUTURE SET. Percentage of samples (taken from each individual set, malicious AND benign) to put in F.
n, k = 2, 3 # number of runs of CEF-SSL
Cm_list = [1, 2]   # COST OF LABELLING. 1=malicious and benign samples have same cost; 2=malicious samples have twice the cost of benign samples; 5=malicious samples have five times the cose of benign samples
Lm_list = [20, 40] # LABELLING BUDGET (in malicious samples). 
active_budget = [0.5, 0.5] # either 'regular' or a custom integer
activeLearning_trials = 2 # how many times each "active learning" model is retrained on new randomly chosen samples (falling in the confidence thresholds)

## Confidence. The following parameters assume a "binary" classification task, where the confidence is predicted for both the benign and malicious class. The sum of such confidences is 1
al_confidences = ['high', 'mid', 'low'] # which are the confidence ranges to be used in the active-learning methods
high_confidence_window = 0.2 # samples whose confidence is ABOVE (100-high_confidence_window/2) are considered to be of "high confidence"
low_confidence_window = 0.2 # samples whose confidence is BELOW (low_confidence_window/2) are considered to be of "high confidence"


# choose the basic classification algorithm here
base_clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                 min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, 
                 min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=-2, 
                 random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
# base_clf = HistGradientBoostingClassifier()

# %%
###### LOAD DATASET

features = pd.Index(['Protocol', 'FlowDuration', 'TotalFwdPacket', 'TotalBwdpackets',
       'TotalLengthofFwdPacket', 'TotalLengthofBwdPacket',
       'FwdPacketLengthMax', 'FwdPacketLengthMin', 'FwdPacketLengthMean',
       'FwdPacketLengthStd', 'BwdPacketLengthMax', 'BwdPacketLengthMin',
       'BwdPacketLengthMean', 'BwdPacketLengthStd', 'FlowBytes/s',
       'FlowPackets/s', 'FlowIATMean', 'FlowIATStd', 'FlowIATMax',
       'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd', 'FwdIATMax',
       'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd', 'BwdIATMax',
       'BwdIATMin', 'FwdPSHFlags', 'BwdPSHFlags', 'FwdURGFlags', 'BwdURGFlags',
       'FwdHeaderLength', 'BwdHeaderLength', 'FwdPackets/s', 'BwdPackets/s',
       'PacketLengthMin', 'PacketLengthMax', 'PacketLengthMean',
       'PacketLengthStd', 'PacketLengthVariance', 'FINFlagCount',
       'SYNFlagCount', 'RSTFlagCount', 'PSHFlagCount', 'ACKFlagCount',
       'URGFlagCount', 'CWRFlagCount', 'ECEFlagCount', 'Down/UpRatio',
       'AveragePacketSize', 'FwdSegmentSizeAvg', 'BwdSegmentSizeAvg',
       'FwdBytes/BulkAvg', 'FwdPacket/BulkAvg', 'FwdBulkRateAvg',
       'BwdBytes/BulkAvg', 'BwdPacket/BulkAvg', 'BwdBulkRateAvg',
       'SubflowFwdPackets', 'SubflowFwdBytes', 'SubflowBwdPackets',
       'SubflowBwdBytes', 'FWDInitWinBytes', 'BwdInitWinBytes',
       'FwdActDataPkts', 'FwdSegSizeMin', 'ActiveMean', 'ActiveStd',
       'ActiveMax', 'ActiveMin', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin',
       'SrcPort_type_fact', 'DstPort_type_fact',
       'DstIP_internal', 'SrcIP_internal'])

label_name = 'Label2'

dataset_file = "./ids17.zip"
df = pd.read_csv(dataset_file, index_col=0)
# df = load_dataset(dataset_file) # load dataset into a dataframe


malicious_families = ['Any'] 
malicious_df_list = []
# malicious_files = ["maliciious_dataset_file1", "malicious_dataset_file2"]
for index, family in enumerate(malicious_families):
    malicious_df_list.append(df[df[label_name]==True])
    #    malicious_df_list.append(load_dataset(malicious_files[index]))
# benign_df = load_dataset(benign_dataset_file)

# %%
for Cm in Cm_list:
    for Lm in Lm_list:
        Lb = Lm * Cm 
        Lcost = Lb + Lm
        
        leftout_budget = int(Lm * (1-active_budget[0])) + int(Lb * (1-active_budget[1]))
        
        print("Lm: {} Cm: {} --> Lb: {} ==> Lcost: {}. Active Learning will use {}Lb and {}Lm initially, and will label at most {} additional samples."
              .format(Lm, Cm, Lb, Lcost, int(Lb*active_budget[0]), int(Lm*active_budget[1]), leftout_budget))
executions_total = n * k * len(Cm_list) * len(Lm_list) * len(malicious_families)
print("\nCEF-SsL performs ({}*{}) runs for each combination above.\nBecause there are {} malicious families, the total amount of executions of CEF-SsL are: {}".format(n, k, len(malicious_families), executions_total))
# Out:
# Lm: 20 Cm: 1 --> Lb: 20 ==> Lcost: 40. Active Learning will use 10Lb and 10Lm initially, and will label at most 20 additional samples.
# Lm: 40 Cm: 1 --> Lb: 40 ==> Lcost: 80. Active Learning will use 20Lb and 20Lm initially, and will label at most 40 additional samples.
# Lm: 20 Cm: 2 --> Lb: 40 ==> Lcost: 60. Active Learning will use 20Lb and 10Lm initially, and will label at most 30 additional samples.
# Lm: 40 Cm: 2 --> Lb: 80 ==> Lcost: 120. Active Learning will use 40Lb and 20Lm initially, and will label at most 60 additional samples.
#
# CEF-SsL performs (2*3) runs for each combination above.
# Because there are 1 malicious families, the total amount of executions of CEF-SsL are: 24

# %%
for index, family in enumerate(malicious_families):
    begin = time.time()
    benign_df = df[df[label_name]==False]
    malicious_df = malicious_df_list[index]
    print("Benign:{}\tMalicious:{}\t({})".format(len(benign_df), len(malicious_df), family))
    for Cm in Cm_list:
        for Lm in Lm_list:
            for reiterate in range(k):
                # We create a new F
                print("reiterate: {} on {}".format(reiterate, k))
                malicious_df['holdout'] = (np.random.uniform(0,1,len(malicious_df)) <= F_holdout)
                benign_df['holdout'] = (np.random.uniform(0,1,len(benign_df)) <= F_holdout)
                malicious_F_df, malicious_UL_df = malicious_df[malicious_df['holdout']==True], malicious_df[malicious_df['holdout']==False]
                benign_F_df, benign_UL_df = benign_df[benign_df['holdout']==True], benign_df[benign_df['holdout']==False]
                
                
                F_df = pd.concat([malicious_F_df, benign_F_df])
                
                print("Size of F (test data): {} ben {} mal ({} tot)".format(len(benign_F_df), len(malicious_F_df), len(F_df)))
                
                F_labels = F_df[label_name]
                UL_df = pd.concat([malicious_UL_df, benign_UL_df])
                UL_labels = UL_df[label_name]
                for run in range(n):
                    print("\trun {} of {} (for reiterate: {} on {})".format(run, n, reiterate, k))
                    Lb = int(Lm * Cm)
                    Lcost = Lb + Lm
                    malicious_L_df = malicious_UL_df.sample(n=Lm)
                    benign_L_df = benign_UL_df.sample(n=Lb)
                    malicious_U_df = malicious_UL_df.drop(malicious_L_df.index)
                    benign_U_df = benign_UL_df.drop(benign_L_df.index)
                    L_df = pd.concat([malicious_L_df, benign_L_df])
                    L_labels = L_df[label_name]
                    U_df = pd.concat([malicious_U_df, benign_U_df])
                    U_labels = U_df[label_name]
                    
                    print("\t\tSL (UpperBound). Large L: {}b {}m\t"
                          .format(len(benign_L_df)+len(benign_U_df), len(malicious_L_df)+len(malicious_U_df), len(UL_df)), end=" ")
                    SL_clf, SL_precision, SL_recall, SL_fscore, SL_trainTime, SL_testTime, SL_Fpredictions = train_test(train_df=UL_df, train_labels=UL_labels, 
                                                                                         test_df=F_df, test_labels=F_labels, features=features, messages=1, base_clf=base_clf)
                    print("F1: {:.5f} TrainTime: {:.3f}s".format(SL_fscore, SL_trainTime))
                    
                    print("\t\tsl (LowerBound). L: {}b {}m\t"
                          .format(len(benign_L_df), len(malicious_L_df), len(L_df)), end="")
                    sl_clf, sl_precision, sl_recall, sl_fscore, sl_trainTime, sl_testTime, sl_Fpredictions = train_test(train_df=L_df, train_labels=L_labels, 
                                                                                         test_df=F_df, test_labels=F_labels, features=features, messages=1, base_clf=base_clf)
                    print("F1: {:.5f} TrainTime: {:.3f}s".format(sl_fscore, sl_trainTime))
                    #########################
                    ##### VANILLA Pseudo Labelling
                    ## PREPARE    
                    start_time = time.time()
                    sl_Upredictions, sl_Uprobabilities = sl_clf.predict(U_df[features]), sl_clf.predict_proba(U_df[features])
                    sl_predictTime = time.time() - start_time

                    # Create column for Predictions on dataframes
                    U_df['sl_prediction'] = sl_Upredictions
                    L_df['sl_prediction'] = L_df[label_name] # dummy column (the pseudo-labelling models will use this column as 'label')

                    # Assign predicted probability (higher probability=more likely that it is benign)
                    U_df['sl_probability'] = (np.hsplit(sl_Uprobabilities,2))[0]

                    # Assign confidence based on (predicted) probability and split dataframe
                    U_df, U_high_df, U_mid_df, U_low_df = assign_confidence(U_df, high_confidence_window, low_confidence_window, 
                                                                                        probability_column_name = 'sl_probability', confidence_column_name = 'sl_confidence', debug=False, split=True)
            

                    pseudoAll_L_df = pd.concat([U_df, L_df])
                    pseudoAll_L_labels = pseudoAll_L_df['sl_prediction']
                    
                    
                    ## TRAIN and TEST
                    print("\t\tBaseline ssl (all pseudo labels). L: {}b {}m\t"
                          .format(len(benign_L_df), len(malicious_L_df)), end="")
                    ssl_clf, ssl_precision, ssl_recall, ssl_fscore, ssl_trainTime, ssl_testTime, ssl_Fpredictions = train_test(train_df=pseudoAll_L_df, train_labels=pseudoAll_L_labels, 
                                                                                         test_df=F_df, test_labels=F_labels, features=features, messages=1, base_clf=base_clf)
                    ssl_trainTime = ssl_trainTime + sl_predictTime + sl_trainTime
                    print("F1: {:.5f} TrainTime: {:.3f}s".format(ssl_fscore, ssl_trainTime))
                    
                    pseudoHigh_L_df = pd.concat([U_high_df, L_df])
                    pseudoHigh_L_labels = pseudoHigh_L_df['sl_prediction']
                    print("\t\tpssl (high confidence pseudo labels). L: {}b {}m\t".
                          format(len(benign_L_df), len(malicious_L_df)), end="")
                    pssl_clf, pssl_precision, pssl_recall, pssl_fscore, pssl_trainTime, pssl_testTime, pssl_Fpredictions = train_test(train_df=pseudoHigh_L_df, train_labels=pseudoHigh_L_labels, 
                                                                                         test_df=F_df, test_labels=F_labels, features=features, messages=1, base_clf=base_clf)
                    pssl_trainTime = pssl_trainTime + sl_predictTime + sl_trainTime
                    print("F1: {:.5f} TrainTime: {:.3f}s".format(pssl_fscore, pssl_trainTime))
                    
                    U_midlow_df = pd.concat([U_mid_df, U_low_df])
                    start_time = time.time()
                    ssl_Umlpredictions, ssl_Umlprobabilities = ssl_clf.predict(U_midlow_df[features]), ssl_clf.predict_proba(U_midlow_df[features])
                    ssl_predictTime = time.time() - start_time
                    U_midlow_df['ssl_prediction'] = ssl_Umlpredictions
                    pseudoHigh_L_df['ssl_prediction'] = pseudoHigh_L_df['sl_prediction'] # dummy column (the retrained pseudo-labelling models will use this column as 'label')
                    U_midlow_df['ssl_probability'] = (np.hsplit(ssl_Umlprobabilities,2))[0]
                    U_midlow_df, U_midlow_high_df, U_midlow_mid_df, U_midlow_low_df = assign_confidence(U_midlow_df, high_confidence_window, low_confidence_window, 
                                                                                        probability_column_name = 'ssl_probability', confidence_column_name = 'ssl_confidence', debug=False, split=True)
                    pseudoHigh_high_L_df = pd.concat([pseudoHigh_L_df, U_midlow_high_df])
                    pseudoHigh_high_L_labels = pseudoHigh_high_L_df['ssl_prediction']
                    
                    
                    print("\t\trpssl (high confidence pseudo labels, twice). L: {}b {}m\t".
                          format(len(benign_L_df), len(malicious_L_df)), end="")
                    rpssl_clf, rpssl_precision, rpssl_recall, rpssl_fscore, rpssl_trainTime, rpssl_testTime, rpssl_Fpredictions = train_test(train_df=pseudoHigh_high_L_df, train_labels=pseudoHigh_high_L_labels, 
                                                                                         test_df=F_df, test_labels=F_labels, features=features, messages=1, base_clf=base_clf)
                    rpssl_trainTime = rpssl_trainTime + pssl_trainTime
                    print("F1: {:.5f} TrainTime: {:.3f}s".format(rpssl_fscore, rpssl_trainTime))
                    
                    ############ ACTIVE LEARNING
                    #### This is for the support model to use for active learning
                    # generating support L
                    malicious_support_L_df = malicious_L_df.sample(n=int(Lm * active_budget[0]))
                    benign_support_L_df = benign_L_df.sample(n=int(Lb * active_budget[1]))
                    support_L_df = pd.concat([malicious_support_L_df, benign_support_L_df])
                    support_L_labels = support_L_df[label_name]
                    
                    # regenerating U
                    malicious_UL_df = malicious_df[malicious_df['holdout']==False]
                    benign_UL_df = benign_df[benign_df['holdout']==False]
                    malicious_U_df = malicious_UL_df.drop(malicious_support_L_df.index)
                    benign_U_df = benign_UL_df.drop(benign_support_L_df.index)
                    support_U_df = pd.concat([malicious_U_df, benign_U_df])
                    support_U_labels = support_U_df[label_name]
                    
                    # training support sl and predicting labels on the (new) U
                    support_sl_clf, support_sl_precision, support_sl_recall, support_sl_fscore, support_sl_trainTime, support_sl_testTime, support_sl_Fpredictions = train_test(train_df=support_L_df, train_labels=support_L_labels, 
                                                                                         test_df=F_df, test_labels=F_labels, features=features, messages=0, base_clf=base_clf)
                    
                    start_time = time.time()
                    support_sl_Upredictions, support_sl_Uprobabilities = support_sl_clf.predict(support_U_df[features]), support_sl_clf.predict_proba(support_U_df[features])
                    support_sl_predictTime = time.time() - start_time
                    support_U_df['support_sl_prediction'] = support_sl_Upredictions
                    support_L_df['support_sl_prediction'] = support_L_df[label_name] # dummy column (the pseudo-labelling models will use this column as 'label')
                    support_U_df['support_sl_probability'] = (np.hsplit(support_sl_Uprobabilities,2))[0]

                    # Assign confidence based on (predicted) probability and split dataframe
                    support_U_df, support_U_high_df, support_U_mid_df, support_U_low_df = assign_confidence(support_U_df, high_confidence_window, low_confidence_window, 
                                                                                        probability_column_name = 'support_sl_probability', confidence_column_name = 'support_sl_confidence', debug=False, split=True)
                    
                    
                    # Train and Test - VANILLA Active Learning
                    leftout_budget = int(Lm * (1-active_budget[0])) + int(Lb * (1-active_budget[1]))
                    
                    if 'high' in al_confidences:
                        print("\t\tahssl (active-high confidence)... L: {}b {}m + {} leftout...\t".
                          format(len(benign_support_L_df), len(malicious_support_L_df), leftout_budget), end=" ")
                        ahssl_precision, ahssl_recall, ahssl_fscore, ahssl_trainTime = active_learning(confidences_df=support_U_high_df, 
                                                                                                          baseTrain_df=support_L_df, 
                                                                                                          validation_df=F_df, 
                                                                                                          features=features, base_clf=base_clf,
                                                                                                          trials=activeLearning_trials, ssl=False, samples=leftout_budget, label_name = label_name, messages=1)
                        ahssl_trainTime = ahssl_trainTime + support_sl_predictTime + support_sl_trainTime
                        print("F1: {:.5f} TrainTime: {:.3f}s".format(ahssl_fscore, ahssl_trainTime))
                        
                    if 'mid' in al_confidences:
                        print("\t\taossl (active-mid confidence)... L: {}b {}m + {} leftout...\t".
                          format(len(benign_support_L_df), len(malicious_support_L_df), leftout_budget), end=" ")
                        aossl_precision, aossl_recall, aossl_fscore, aossl_trainTime = active_learning(confidences_df=support_U_mid_df, 
                                                                                                           baseTrain_df=support_L_df, 
                                                                                                           validation_df=F_df, 
                                                                                                           features=features, base_clf=base_clf,
                                                                                                           trials=activeLearning_trials, ssl=False, samples=leftout_budget, label_name = label_name, messages=1)
                        aossl_trainTime = aossl_trainTime + support_sl_predictTime + support_sl_trainTime
                        print("F1: {:.5f} TrainTime: {:.3f}s".format(aossl_fscore, aossl_trainTime))
                    if 'low' in al_confidences:
                        print("\t\talssl (active-low confidence)... L: {}b {}m + {} leftout...\t".
                          format(len(benign_support_L_df), len(malicious_support_L_df), leftout_budget), end=" ")
                        alssl_precision, alssl_recall, alssl_fscore, alssl_trainTime = active_learning(confidences_df=support_U_low_df, 
                                                                                                           baseTrain_df=support_L_df, 
                                                                                                           validation_df=F_df, 
                                                                                                           features=features, base_clf=base_clf,
                                                                                                           trials=activeLearning_trials, ssl=False, samples=leftout_budget, label_name = label_name, messages=1)
                        alssl_trainTime = alssl_trainTime + support_sl_predictTime + support_sl_trainTime
                        print("F1: {:.5f} TrainTime: {:.3f}s".format(alssl_fscore, alssl_trainTime))
                    ############
                    #### PREPARE: Pseudo Labelling + Active Learning
                    
                    ## First, train the support pseudo-labelling model using the labels with high-confidence
                    support_L_df['support_sl_prediction'] = support_L_df[label_name]
                    pseudoHigh_support_L_df = pd.concat([support_U_high_df, support_L_df])
                    pseudoHigh_support_L_labels = pseudoHigh_support_L_df['support_sl_prediction']
                    
                    
                    print("\t\tPseudo-Active Learning: the base size of the training set is: {}".format(len(pseudoHigh_support_L_df)))
                    support_pssl_clf, support_pssl_precision, support_pssl_recall, support_pssl_fscore, support_pssl_trainTime, support_pssl_testTime, support_pssl_Fpredictions = train_test(train_df=pseudoHigh_support_L_df, train_labels=pseudoHigh_support_L_labels, 
                                                                                         test_df=F_df, test_labels=F_labels, features=features, messages=0, base_clf=base_clf)
                    support_pssl_trainTime = support_pssl_trainTime + support_sl_trainTime + support_sl_predictTime
                    
                    ## Then, use such support pseudo-labelling to predict the confidence of the remaining samples in U
                    support_U_midlow_df = pd.concat([support_U_mid_df, support_U_low_df])
                    start_time = time.time()
                    support_pssl_Umlpredictions, support_pssl_Umlprobabilities = support_pssl_clf.predict(support_U_midlow_df[features]), support_pssl_clf.predict_proba(support_U_midlow_df[features])
                    support_pssl_predictTime = time.time() - start_time
                    support_U_midlow_df['support_ssl_prediction'] = support_pssl_Umlpredictions
                    pseudoHigh_support_L_df['support_ssl_prediction'] = pseudoHigh_support_L_df['support_sl_prediction'] # dummy column (the retrained pseudo-labelling models will use this column as 'label')
                    support_U_midlow_df['support_ssl_probability'] = (np.hsplit(support_pssl_Umlprobabilities,2))[0]
                    support_U_midlow_df, support_U_midlow_high_df, support_U_midlow_mid_df, support_U_midlow_low_df = assign_confidence(support_U_midlow_df, high_confidence_window, low_confidence_window,
                                                                                                                                        probability_column_name = 'support_ssl_probability', confidence_column_name = 'support_ssl_confidence', debug=False, split=True)
                    
                    ## TRAIN and TEST - Pesudo-Active Learning
                    if 'high' in al_confidences:
                        print("\t\tpahssl (pseudoActive-high confidence)... L: {}b {}m + {} leftout...\t".
                          format(len(benign_support_L_df), len(malicious_support_L_df), leftout_budget), end=" ")
                        pahssl_precision, pahssl_recall, pahssl_fscore, pahssl_trainTime = active_learning(confidences_df=support_U_midlow_high_df, 
                                                                                                          baseTrain_df=pseudoHigh_support_L_df, 
                                                                                                          validation_df=F_df, 
                                                                                                          features=features, base_clf=base_clf,
                                                                                                          trials=activeLearning_trials, ssl=True, samples=leftout_budget, label_name = label_name, messages=1)
                        pahssl_trainTime = pahssl_trainTime + support_pssl_trainTime + support_pssl_predictTime
                        print("F1: {:.5f} TrainTime: {:.3f}s".format(pahssl_fscore, pahssl_trainTime))
                    if 'mid' in al_confidences:
                        print("\t\tpahssl (pseudoActive-mid confidence)... L: {}b {}m + {} leftout...\t".
                          format(len(benign_support_L_df), len(malicious_support_L_df), leftout_budget), end=" ")
                        paossl_precision, paossl_recall, paossl_fscore, paossl_trainTime = active_learning(confidences_df=support_U_midlow_mid_df, 
                                                                                                           baseTrain_df=pseudoHigh_support_L_df, 
                                                                                                           validation_df=F_df, 
                                                                                                           features=features, base_clf=base_clf,
                                                                                                           trials=activeLearning_trials, ssl=True, samples=leftout_budget, label_name = label_name, messages=1)
                        paossl_trainTime = paossl_trainTime + support_pssl_trainTime + support_pssl_predictTime
                        print("F1: {:.5f} TrainTime: {:.3f}s".format(paossl_fscore, paossl_trainTime))
                    if 'low' in al_confidences:
                        print("\t\tpahssl (pseudoActive-low confidence)... L: {}b {}m + {} leftout...\t".
                          format(len(benign_support_L_df), len(malicious_support_L_df), leftout_budget), end=" ")
                        palssl_precision, palssl_recall, palssl_fscore, palssl_trainTime = active_learning(confidences_df=support_U_midlow_low_df, 
                                                                                                           baseTrain_df=pseudoHigh_support_L_df, 
                                                                                                           validation_df=F_df, 
                                                                                                           features=features, base_clf=base_clf,
                                                                                                           trials=activeLearning_trials, ssl=True, samples=leftout_budget, label_name = label_name, messages=1)
                        palssl_trainTime = palssl_trainTime + support_pssl_trainTime + support_pssl_predictTime
                        print("F1: {:.5f} TrainTime: {:.3f}s".format(palssl_fscore, palssl_trainTime))
runtime = time.time() - begin
print("Runtime total: {:.5f}".format(runtime))
# Out:
# Benign:100000	Malicious:10000	(Any)
# reiterate: 0 on 3
# Size of F (test data): 20262 ben 2028 mal (22290 tot)
# 	run 0 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 79735b 7972m	 Train size: 87710---F1: 0.99508 TrainTime: 4.237s
# 		sl (LowerBound). L: 20b 20m	Train size: 40---F1: 0.90599 TrainTime: 0.240s
# 		Baseline ssl (all pseudo labels). L: 20b 20m	Train size: 87707---F1: 0.90557 TrainTime: 6.474s
# 		pssl (high confidence pseudo labels). L: 20b 20m	Train size: 69954---F1: 0.93524 TrainTime: 3.379s
# 		rpssl (high confidence pseudo labels, twice). L: 20b 20m	Train size: 87469---F1: 0.90666 TrainTime: 7.311s
# 		ahssl (active-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.78662 TrainTime: 1.494s
# 		aossl (active-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.86557 TrainTime: 1.491s
# 		alssl (active-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.93157 TrainTime: 1.489s
# 		Pseudo-Active Learning: the base size of the training set is: 19485
# 		pahssl (pseudoActive-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 19505---F1: 0.82809 TrainTime: 3.379s
# 		pahssl (pseudoActive-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 19505---F1: 0.87048 TrainTime: 3.372s
# 		pahssl (pseudoActive-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 19505---F1: 0.92601 TrainTime: 3.332s
# 	run 1 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 79732b 7972m	 Train size: 87710---F1: 0.99434 TrainTime: 3.446s
# 		sl (LowerBound). L: 20b 20m	Train size: 40---F1: 0.90530 TrainTime: 0.186s
# 		Baseline ssl (all pseudo labels). L: 20b 20m	Train size: 87704---F1: 0.90704 TrainTime: 6.008s
# 		pssl (high confidence pseudo labels). L: 20b 20m	Train size: 61801---F1: 0.91244 TrainTime: 2.495s
# 		rpssl (high confidence pseudo labels, twice). L: 20b 20m	Train size: 87397---F1: 0.91043 TrainTime: 6.399s
# 		ahssl (active-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.54208 TrainTime: 1.452s
# 		aossl (active-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.93168 TrainTime: 1.446s
# 		alssl (active-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.86292 TrainTime: 1.450s
# 		Pseudo-Active Learning: the base size of the training set is: 50379
# 		pahssl (pseudoActive-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 50399---F1: 0.50421 TrainTime: 3.271s
# 		pahssl (pseudoActive-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 50399---F1: 0.91418 TrainTime: 3.310s
# 		pahssl (pseudoActive-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 50399---F1: 0.87480 TrainTime: 3.317s
# reiterate: 1 on 3
# Size of F (test data): 20150 ben 2002 mal (22152 tot)
# 	run 0 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 79847b 7998m	 Train size: 87848---F1: 0.99651 TrainTime: 3.302s
# 		sl (LowerBound). L: 20b 20m	Train size: 40---F1: 0.89045 TrainTime: 0.184s
# 		Baseline ssl (all pseudo labels). L: 20b 20m	Train size: 87845---F1: 0.89348 TrainTime: 5.167s
# 		pssl (high confidence pseudo labels). L: 20b 20m	Train size: 63382---F1: 0.85167 TrainTime: 2.356s
# 		rpssl (high confidence pseudo labels, twice). L: 20b 20m	Train size: 87464---F1: 0.89833 TrainTime: 5.730s
# 		ahssl (active-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.82069 TrainTime: 1.372s
# 		aossl (active-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.79784 TrainTime: 1.375s
# 		alssl (active-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.91764 TrainTime: 1.375s
# 		Pseudo-Active Learning: the base size of the training set is: 44942
# 		pahssl (pseudoActive-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 44962---F1: 0.76493 TrainTime: 2.980s
# 		pahssl (pseudoActive-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 44962---F1: 0.92424 TrainTime: 3.023s
# 		pahssl (pseudoActive-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 44962---F1: 0.94907 TrainTime: 3.010s
# 	run 1 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 79847b 7998m	 Train size: 87848---F1: 0.99651 TrainTime: 2.967s
# 		sl (LowerBound). L: 20b 20m	Train size: 40---F1: 0.89088 TrainTime: 0.188s
# 		Baseline ssl (all pseudo labels). L: 20b 20m	Train size: 87845---F1: 0.89463 TrainTime: 5.529s
# 		pssl (high confidence pseudo labels). L: 20b 20m	Train size: 54142---F1: 0.94932 TrainTime: 1.962s
# 		rpssl (high confidence pseudo labels, twice). L: 20b 20m	Train size: 87390---F1: 0.89953 TrainTime: 5.811s
# 		ahssl (active-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.85129 TrainTime: 1.394s
# 		aossl (active-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.95717 TrainTime: 1.397s
# 		alssl (active-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.92095 TrainTime: 1.398s
# 		Pseudo-Active Learning: the base size of the training set is: 51460
# 		pahssl (pseudoActive-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 51480---F1: 0.82058 TrainTime: 3.204s
# 		pahssl (pseudoActive-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 51480---F1: 0.92554 TrainTime: 3.268s
# 		pahssl (pseudoActive-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 51480---F1: 0.97658 TrainTime: 3.249s
# reiterate: 2 on 3
# Size of F (test data): 19776 ben 2005 mal (21781 tot)
# 	run 0 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 80223b 7995m	 Train size: 88219---F1: 0.99652 TrainTime: 3.025s
# 		sl (LowerBound). L: 20b 20m	Train size: 40---F1: 0.82867 TrainTime: 0.184s
# 		Baseline ssl (all pseudo labels). L: 20b 20m	Train size: 88218---F1: 0.82624 TrainTime: 4.871s
# 		pssl (high confidence pseudo labels). L: 20b 20m	Train size: 69559---F1: 0.71317 TrainTime: 2.504s
# 		rpssl (high confidence pseudo labels, twice). L: 20b 20m	Train size: 87874---F1: 0.82538 TrainTime: 5.998s
# 		ahssl (active-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.87697 TrainTime: 1.417s
# 		aossl (active-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.94286 TrainTime: 1.420s
# 		alssl (active-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.88313 TrainTime: 1.421s
# 		Pseudo-Active Learning: the base size of the training set is: 51411
# 		pahssl (pseudoActive-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 51431---F1: 0.93550 TrainTime: 3.083s
# 		pahssl (pseudoActive-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 51431---F1: 0.93150 TrainTime: 3.114s
# 		pahssl (pseudoActive-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 51431---F1: 0.93894 TrainTime: 3.119s
# 	run 1 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 80221b 7995m	 Train size: 88219---F1: 0.99652 TrainTime: 2.934s
# 		sl (LowerBound). L: 20b 20m	Train size: 40---F1: 0.85153 TrainTime: 0.182s
# 		Baseline ssl (all pseudo labels). L: 20b 20m	Train size: 88216---F1: 0.85310 TrainTime: 4.623s
# 		pssl (high confidence pseudo labels). L: 20b 20m	Train size: 68516---F1: 0.84875 TrainTime: 2.389s
# 		rpssl (high confidence pseudo labels, twice). L: 20b 20m	Train size: 87871---F1: 0.85185 TrainTime: 5.567s
# 		ahssl (active-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.86037 TrainTime: 1.429s
# 		aossl (active-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.90502 TrainTime: 1.424s
# 		alssl (active-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 40---F1: 0.91567 TrainTime: 1.428s
# 		Pseudo-Active Learning: the base size of the training set is: 51535
# 		pahssl (pseudoActive-high confidence)... L: 10b 10m + 20 leftout...	 Train size: 51555---F1: 0.81890 TrainTime: 3.119s
# 		pahssl (pseudoActive-mid confidence)... L: 10b 10m + 20 leftout...	 Train size: 51555---F1: 0.94313 TrainTime: 3.134s
# 		pahssl (pseudoActive-low confidence)... L: 10b 10m + 20 leftout...	 Train size: 51555---F1: 0.92398 TrainTime: 3.182s
# reiterate: 0 on 3
# Size of F (test data): 19972 ben 1999 mal (21971 tot)
# 	run 0 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 80017b 8001m	 Train size: 88029---F1: 0.99775 TrainTime: 3.057s
# 		sl (LowerBound). L: 40b 40m	Train size: 80---F1: 0.96245 TrainTime: 0.181s
# 		Baseline ssl (all pseudo labels). L: 40b 40m	Train size: 88018---F1: 0.96440 TrainTime: 4.800s
# 		pssl (high confidence pseudo labels). L: 40b 40m	Train size: 72609---F1: 0.97256 TrainTime: 2.694s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 40m	Train size: 87914---F1: 0.96514 TrainTime: 5.932s
# 		ahssl (active-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.84769 TrainTime: 1.544s
# 		aossl (active-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.97969 TrainTime: 1.545s
# 		alssl (active-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.94992 TrainTime: 1.536s
# 		Pseudo-Active Learning: the base size of the training set is: 66380
# 		pahssl (pseudoActive-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 66420---F1: 0.88108 TrainTime: 4.099s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 66420---F1: 0.98601 TrainTime: 4.285s
# 		pahssl (pseudoActive-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 66420---F1: 0.94997 TrainTime: 4.149s
# 	run 1 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 80024b 8001m	 Train size: 88029---F1: 0.99775 TrainTime: 3.236s
# 		sl (LowerBound). L: 40b 40m	Train size: 80---F1: 0.95344 TrainTime: 0.194s
# 		Baseline ssl (all pseudo labels). L: 40b 40m	Train size: 88025---F1: 0.95480 TrainTime: 5.020s
# 		pssl (high confidence pseudo labels). L: 40b 40m	Train size: 68120---F1: 0.95387 TrainTime: 2.736s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 40m	Train size: 87939---F1: 0.95602 TrainTime: 5.730s
# 		ahssl (active-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.91845 TrainTime: 1.412s
# 		aossl (active-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.96008 TrainTime: 1.416s
# 		alssl (active-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.95124 TrainTime: 1.411s
# 		Pseudo-Active Learning: the base size of the training set is: 66129
# 		pahssl (pseudoActive-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 66169---F1: 0.93724 TrainTime: 3.732s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 66169---F1: 0.98753 TrainTime: 3.952s
# 		pahssl (pseudoActive-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 66169---F1: 0.95247 TrainTime: 3.954s
# reiterate: 1 on 3
# Size of F (test data): 20149 ben 2030 mal (22179 tot)
# 	run 0 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 79845b 7970m	 Train size: 87821---F1: 0.99656 TrainTime: 3.450s
# 		sl (LowerBound). L: 40b 40m	Train size: 80---F1: 0.88123 TrainTime: 0.198s
# 		Baseline ssl (all pseudo labels). L: 40b 40m	Train size: 87815---F1: 0.88197 TrainTime: 4.339s
# 		pssl (high confidence pseudo labels). L: 40b 40m	Train size: 71581---F1: 0.92519 TrainTime: 2.679s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 40m	Train size: 87773---F1: 0.88197 TrainTime: 5.576s
# 		ahssl (active-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.86764 TrainTime: 1.396s
# 		aossl (active-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.96181 TrainTime: 1.401s
# 		alssl (active-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.95369 TrainTime: 1.406s
# 		Pseudo-Active Learning: the base size of the training set is: 67152
# 		pahssl (pseudoActive-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 67192---F1: 0.87273 TrainTime: 3.797s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 67192---F1: 0.98203 TrainTime: 3.874s
# 		pahssl (pseudoActive-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 67192---F1: 0.87674 TrainTime: 3.909s
# 	run 1 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 79848b 7970m	 Train size: 87821---F1: 0.99680 TrainTime: 3.027s
# 		sl (LowerBound). L: 40b 40m	Train size: 80---F1: 0.78930 TrainTime: 0.189s
# 		Baseline ssl (all pseudo labels). L: 40b 40m	Train size: 87818---F1: 0.78913 TrainTime: 5.109s
# 		pssl (high confidence pseudo labels). L: 40b 40m	Train size: 59748---F1: 0.79612 TrainTime: 2.270s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 40m	Train size: 87755---F1: 0.78883 TrainTime: 5.754s
# 		ahssl (active-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.77140 TrainTime: 1.399s
# 		aossl (active-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.97303 TrainTime: 1.403s
# 		alssl (active-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.84613 TrainTime: 1.404s
# 		Pseudo-Active Learning: the base size of the training set is: 59189
# 		pahssl (pseudoActive-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 59229---F1: 0.77040 TrainTime: 3.526s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 59229---F1: 0.97466 TrainTime: 3.653s
# 		pahssl (pseudoActive-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 59229---F1: 0.88593 TrainTime: 3.638s
# reiterate: 2 on 3
# Size of F (test data): 19994 ben 1969 mal (21963 tot)
# 	run 0 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 80000b 8031m	 Train size: 88037---F1: 0.99646 TrainTime: 3.235s
# 		sl (LowerBound). L: 40b 40m	Train size: 80---F1: 0.85626 TrainTime: 0.185s
# 		Baseline ssl (all pseudo labels). L: 40b 40m	Train size: 88031---F1: 0.85708 TrainTime: 4.383s
# 		pssl (high confidence pseudo labels). L: 40b 40m	Train size: 69581---F1: 0.84351 TrainTime: 2.757s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 40m	Train size: 87976---F1: 0.85746 TrainTime: 5.550s
# 		ahssl (active-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.68034 TrainTime: 1.411s
# 		aossl (active-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.94435 TrainTime: 1.415s
# 		alssl (active-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.87113 TrainTime: 1.412s
# 		Pseudo-Active Learning: the base size of the training set is: 62345
# 		pahssl (pseudoActive-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 62385---F1: 0.63143 TrainTime: 3.785s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 62385---F1: 0.95608 TrainTime: 3.798s
# 		pahssl (pseudoActive-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 62385---F1: 0.75816 TrainTime: 3.843s
# 	run 1 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 80000b 8031m	 Train size: 88037---F1: 0.99595 TrainTime: 2.754s
# 		sl (LowerBound). L: 40b 40m	Train size: 80---F1: 0.84978 TrainTime: 0.206s
# 		Baseline ssl (all pseudo labels). L: 40b 40m	Train size: 88031---F1: 0.85072 TrainTime: 4.913s
# 		pssl (high confidence pseudo labels). L: 40b 40m	Train size: 66362---F1: 0.83585 TrainTime: 2.691s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 40m	Train size: 87964---F1: 0.85110 TrainTime: 5.896s
# 		ahssl (active-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.80900 TrainTime: 1.327s
# 		aossl (active-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.94634 TrainTime: 1.327s
# 		alssl (active-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 80---F1: 0.93982 TrainTime: 1.331s
# 		Pseudo-Active Learning: the base size of the training set is: 60969
# 		pahssl (pseudoActive-high confidence)... L: 20b 20m + 40 leftout...	 Train size: 61009---F1: 0.78318 TrainTime: 3.287s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 20m + 40 leftout...	 Train size: 61009---F1: 0.95887 TrainTime: 3.321s
# 		pahssl (pseudoActive-low confidence)... L: 20b 20m + 40 leftout...	 Train size: 61009---F1: 0.93225 TrainTime: 3.313s
# reiterate: 0 on 3
# Size of F (test data): 20014 ben 2027 mal (22041 tot)
# 	run 0 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 79977b 7973m	 Train size: 87959---F1: 0.99803 TrainTime: 2.761s
# 		sl (LowerBound). L: 40b 20m	Train size: 60---F1: 0.82641 TrainTime: 0.180s
# 		Baseline ssl (all pseudo labels). L: 40b 20m	Train size: 87950---F1: 0.82746 TrainTime: 4.077s
# 		pssl (high confidence pseudo labels). L: 40b 20m	Train size: 74426---F1: 0.82062 TrainTime: 2.320s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 20m	Train size: 87800---F1: 0.82746 TrainTime: 5.119s
# 		ahssl (active-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.87525 TrainTime: 1.342s
# 		aossl (active-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.93710 TrainTime: 1.336s
# 		alssl (active-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.87808 TrainTime: 1.333s
# 		Pseudo-Active Learning: the base size of the training set is: 73186
# 		pahssl (pseudoActive-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 73216---F1: 0.86003 TrainTime: 3.513s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 73216---F1: 0.88571 TrainTime: 3.772s
# 		pahssl (pseudoActive-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 73216---F1: 0.91899 TrainTime: 3.646s
# 	run 1 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 79982b 7973m	 Train size: 87959---F1: 0.99778 TrainTime: 2.672s
# 		sl (LowerBound). L: 40b 20m	Train size: 60---F1: 0.84775 TrainTime: 0.177s
# 		Baseline ssl (all pseudo labels). L: 40b 20m	Train size: 87955---F1: 0.85069 TrainTime: 4.364s
# 		pssl (high confidence pseudo labels). L: 40b 20m	Train size: 76144---F1: 0.91172 TrainTime: 2.485s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 20m	Train size: 87727---F1: 0.85254 TrainTime: 5.479s
# 		ahssl (active-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.77235 TrainTime: 1.279s
# 		aossl (active-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.93826 TrainTime: 1.276s
# 		alssl (active-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.92270 TrainTime: 1.279s
# 		Pseudo-Active Learning: the base size of the training set is: 71523
# 		pahssl (pseudoActive-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 71553---F1: 0.77664 TrainTime: 3.519s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 71553---F1: 0.95087 TrainTime: 3.655s
# 		pahssl (pseudoActive-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 71553---F1: 0.89810 TrainTime: 3.517s
# reiterate: 1 on 3
# Size of F (test data): 20130 ben 2041 mal (22171 tot)
# 	run 0 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 79863b 7959m	 Train size: 87829---F1: 0.99609 TrainTime: 2.969s
# 		sl (LowerBound). L: 40b 20m	Train size: 60---F1: 0.78389 TrainTime: 0.175s
# 		Baseline ssl (all pseudo labels). L: 40b 20m	Train size: 87822---F1: 0.78413 TrainTime: 4.311s
# 		pssl (high confidence pseudo labels). L: 40b 20m	Train size: 68188---F1: 0.83962 TrainTime: 2.168s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 20m	Train size: 87719---F1: 0.78389 TrainTime: 4.917s
# 		ahssl (active-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.71907 TrainTime: 1.294s
# 		aossl (active-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.93181 TrainTime: 1.289s
# 		alssl (active-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.93796 TrainTime: 1.288s
# 		Pseudo-Active Learning: the base size of the training set is: 63481
# 		pahssl (pseudoActive-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 63511---F1: 0.75057 TrainTime: 3.257s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 63511---F1: 0.91269 TrainTime: 3.330s
# 		pahssl (pseudoActive-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 63511---F1: 0.91474 TrainTime: 3.258s
# 	run 1 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 79866b 7959m	 Train size: 87829---F1: 0.99609 TrainTime: 2.832s
# 		sl (LowerBound). L: 40b 20m	Train size: 60---F1: 0.90586 TrainTime: 0.177s
# 		Baseline ssl (all pseudo labels). L: 40b 20m	Train size: 87825---F1: 0.90616 TrainTime: 3.798s
# 		pssl (high confidence pseudo labels). L: 40b 20m	Train size: 59832---F1: 0.93210 TrainTime: 2.183s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 20m	Train size: 87736---F1: 0.90629 TrainTime: 4.597s
# 		ahssl (active-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.89662 TrainTime: 1.307s
# 		aossl (active-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.92602 TrainTime: 1.298s
# 		alssl (active-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.97722 TrainTime: 1.300s
# 		Pseudo-Active Learning: the base size of the training set is: 55612
# 		pahssl (pseudoActive-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 55642---F1: 0.86762 TrainTime: 3.531s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 55642---F1: 0.93972 TrainTime: 3.623s
# 		pahssl (pseudoActive-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 55642---F1: 0.94450 TrainTime: 3.551s
# reiterate: 2 on 3
# Size of F (test data): 19770 ben 1961 mal (21731 tot)
# 	run 0 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 80222b 8039m	 Train size: 88269---F1: 0.99465 TrainTime: 2.889s
# 		sl (LowerBound). L: 40b 20m	Train size: 60---F1: 0.93205 TrainTime: 0.182s
# 		Baseline ssl (all pseudo labels). L: 40b 20m	Train size: 88261---F1: 0.93458 TrainTime: 4.296s
# 		pssl (high confidence pseudo labels). L: 40b 20m	Train size: 76397---F1: 0.93153 TrainTime: 2.489s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 20m	Train size: 88097---F1: 0.93597 TrainTime: 5.268s
# 		ahssl (active-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.73531 TrainTime: 1.311s
# 		aossl (active-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.93336 TrainTime: 1.314s
# 		alssl (active-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.89845 TrainTime: 1.311s
# 		Pseudo-Active Learning: the base size of the training set is: 65272
# 		pahssl (pseudoActive-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 65302---F1: 0.74420 TrainTime: 3.422s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 65302---F1: 0.97348 TrainTime: 3.464s
# 		pahssl (pseudoActive-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 65302---F1: 0.90449 TrainTime: 3.389s
# 	run 1 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 80223b 8039m	 Train size: 88269---F1: 0.99465 TrainTime: 2.582s
# 		sl (LowerBound). L: 40b 20m	Train size: 60---F1: 0.80656 TrainTime: 0.176s
# 		Baseline ssl (all pseudo labels). L: 40b 20m	Train size: 88262---F1: 0.80708 TrainTime: 4.559s
# 		pssl (high confidence pseudo labels). L: 40b 20m	Train size: 76200---F1: 0.82772 TrainTime: 2.414s
# 		rpssl (high confidence pseudo labels, twice). L: 40b 20m	Train size: 88023---F1: 0.80846 TrainTime: 5.576s
# 		ahssl (active-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.76486 TrainTime: 1.296s
# 		aossl (active-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.95662 TrainTime: 1.294s
# 		alssl (active-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 60---F1: 0.92958 TrainTime: 1.304s
# 		Pseudo-Active Learning: the base size of the training set is: 68193
# 		pahssl (pseudoActive-high confidence)... L: 20b 10m + 30 leftout...	 Train size: 68223---F1: 0.74154 TrainTime: 3.519s
# 		pahssl (pseudoActive-mid confidence)... L: 20b 10m + 30 leftout...	 Train size: 68223---F1: 0.97640 TrainTime: 3.919s
# 		pahssl (pseudoActive-low confidence)... L: 20b 10m + 30 leftout...	 Train size: 68223---F1: 0.93524 TrainTime: 3.677s
# reiterate: 0 on 3
# Size of F (test data): 20181 ben 2043 mal (22224 tot)
# 	run 0 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 79811b 7957m	 Train size: 87776---F1: 0.99683 TrainTime: 3.530s
# 		sl (LowerBound). L: 80b 40m	Train size: 120---F1: 0.94926 TrainTime: 0.202s
# 		Baseline ssl (all pseudo labels). L: 80b 40m	Train size: 87768---F1: 0.94943 TrainTime: 4.632s
# 		pssl (high confidence pseudo labels). L: 80b 40m	Train size: 77863---F1: 0.94759 TrainTime: 3.181s
# 		rpssl (high confidence pseudo labels, twice). L: 80b 40m	Train size: 87719---F1: 0.94959 TrainTime: 6.219s
# 		ahssl (active-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.90937 TrainTime: 1.392s
# 		aossl (active-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.96210 TrainTime: 1.396s
# 		alssl (active-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.94217 TrainTime: 1.410s
# 		Pseudo-Active Learning: the base size of the training set is: 72999
# 		pahssl (pseudoActive-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 73059---F1: 0.86198 TrainTime: 4.085s
# 		pahssl (pseudoActive-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 73059---F1: 0.96623 TrainTime: 4.274s
# 		pahssl (pseudoActive-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 73059---F1: 0.94101 TrainTime: 4.171s
# 	run 1 of 2 (for reiterate: 0 on 3)
# 		SL (UpperBound). Large L: 79807b 7957m	 Train size: 87776---F1: 0.99707 TrainTime: 3.051s
# 		sl (LowerBound). L: 80b 40m	Train size: 120---F1: 0.89597 TrainTime: 0.185s
# 		Baseline ssl (all pseudo labels). L: 80b 40m	Train size: 87764---F1: 0.89618 TrainTime: 4.789s
# 		pssl (high confidence pseudo labels). L: 80b 40m	Train size: 79147---F1: 0.88749 TrainTime: 2.772s
# 		rpssl (high confidence pseudo labels, twice). L: 80b 40m	Train size: 87665---F1: 0.89679 TrainTime: 6.014s
# 		ahssl (active-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.84507 TrainTime: 1.385s
# 		aossl (active-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.96291 TrainTime: 1.387s
# 		alssl (active-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.93191 TrainTime: 1.386s
# 		Pseudo-Active Learning: the base size of the training set is: 75330
# 		pahssl (pseudoActive-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 75390---F1: 0.88203 TrainTime: 4.480s
# 		pahssl (pseudoActive-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 75390---F1: 0.96946 TrainTime: 4.449s
# 		pahssl (pseudoActive-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 75390---F1: 0.94261 TrainTime: 4.167s
# reiterate: 1 on 3
# Size of F (test data): 19971 ben 1981 mal (21952 tot)
# 	run 0 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 80008b 8018m	 Train size: 88048---F1: 0.99497 TrainTime: 3.213s
# 		sl (LowerBound). L: 80b 40m	Train size: 120---F1: 0.95412 TrainTime: 0.183s
# 		Baseline ssl (all pseudo labels). L: 80b 40m	Train size: 88026---F1: 0.95511 TrainTime: 4.418s
# 		pssl (high confidence pseudo labels). L: 80b 40m	Train size: 73029---F1: 0.94965 TrainTime: 2.929s
# 		rpssl (high confidence pseudo labels, twice). L: 80b 40m	Train size: 88000---F1: 0.95635 TrainTime: 5.899s
# 		ahssl (active-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.86992 TrainTime: 1.454s
# 		aossl (active-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.97154 TrainTime: 1.453s
# 		alssl (active-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.94397 TrainTime: 1.453s
# 		Pseudo-Active Learning: the base size of the training set is: 75288
# 		pahssl (pseudoActive-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 75348---F1: 0.92267 TrainTime: 4.413s
# 		pahssl (pseudoActive-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 75348---F1: 0.96945 TrainTime: 4.534s
# 		pahssl (pseudoActive-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 75348---F1: 0.96548 TrainTime: 4.474s
# 	run 1 of 2 (for reiterate: 1 on 3)
# 		SL (UpperBound). Large L: 80016b 8019m	 Train size: 88048---F1: 0.99497 TrainTime: 2.998s
# 		sl (LowerBound). L: 80b 40m	Train size: 120---F1: 0.94457 TrainTime: 0.188s
# 		Baseline ssl (all pseudo labels). L: 80b 40m	Train size: 88035---F1: 0.94598 TrainTime: 4.299s
# 		pssl (high confidence pseudo labels). L: 80b 40m	Train size: 79329---F1: 0.94382 TrainTime: 2.922s
# 		rpssl (high confidence pseudo labels, twice). L: 80b 40m	Train size: 87999---F1: 0.94621 TrainTime: 5.675s
# 		ahssl (active-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.89992 TrainTime: 1.467s
# 		aossl (active-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.97551 TrainTime: 1.471s
# 		alssl (active-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.95737 TrainTime: 1.462s
# 		Pseudo-Active Learning: the base size of the training set is: 71319
# 		pahssl (pseudoActive-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 71379---F1: 0.93447 TrainTime: 4.105s
# 		pahssl (pseudoActive-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 71379---F1: 0.98284 TrainTime: 4.505s
# 		pahssl (pseudoActive-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 71379---F1: 0.94100 TrainTime: 4.296s
# reiterate: 2 on 3
# Size of F (test data): 20259 ben 1963 mal (22222 tot)
# 	run 0 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 79727b 8037m	 Train size: 87778---F1: 0.99771 TrainTime: 2.845s
# 		sl (LowerBound). L: 80b 40m	Train size: 120---F1: 0.93448 TrainTime: 0.182s
# 		Baseline ssl (all pseudo labels). L: 80b 40m	Train size: 87764---F1: 0.93586 TrainTime: 4.211s
# 		pssl (high confidence pseudo labels). L: 80b 40m	Train size: 76855---F1: 0.93596 TrainTime: 2.783s
# 		rpssl (high confidence pseudo labels, twice). L: 80b 40m	Train size: 87700---F1: 0.93609 TrainTime: 5.466s
# 		ahssl (active-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.92438 TrainTime: 1.400s
# 		aossl (active-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.95221 TrainTime: 1.401s
# 		alssl (active-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.93653 TrainTime: 1.402s
# 		Pseudo-Active Learning: the base size of the training set is: 76021
# 		pahssl (pseudoActive-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 76081---F1: 0.93638 TrainTime: 4.120s
# 		pahssl (pseudoActive-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 76081---F1: 0.97491 TrainTime: 4.572s
# 		pahssl (pseudoActive-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 76081---F1: 0.97153 TrainTime: 4.319s
# 	run 1 of 2 (for reiterate: 2 on 3)
# 		SL (UpperBound). Large L: 79726b 8037m	 Train size: 87778---F1: 0.99746 TrainTime: 2.959s
# 		sl (LowerBound). L: 80b 40m	Train size: 120---F1: 0.98236 TrainTime: 0.187s
# 		Baseline ssl (all pseudo labels). L: 80b 40m	Train size: 87763---F1: 0.98282 TrainTime: 4.579s
# 		pssl (high confidence pseudo labels). L: 80b 40m	Train size: 70908---F1: 0.96591 TrainTime: 2.776s
# 		rpssl (high confidence pseudo labels, twice). L: 80b 40m	Train size: 87648---F1: 0.98357 TrainTime: 5.811s
# 		ahssl (active-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.95264 TrainTime: 1.411s
# 		aossl (active-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.97270 TrainTime: 1.415s
# 		alssl (active-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 120---F1: 0.99133 TrainTime: 1.413s
# 		Pseudo-Active Learning: the base size of the training set is: 70132
# 		pahssl (pseudoActive-high confidence)... L: 40b 20m + 60 leftout...	 Train size: 70192---F1: 0.96500 TrainTime: 4.330s
# 		pahssl (pseudoActive-mid confidence)... L: 40b 20m + 60 leftout...	 Train size: 70192---F1: 0.98860 TrainTime: 4.448s
# 		pahssl (pseudoActive-low confidence)... L: 40b 20m + 60 leftout...	 Train size: 70192---F1: 0.98157 TrainTime: 4.399s
# Runtime total: 668.49984
